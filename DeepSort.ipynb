# %% [markdown]
# <a href="https://colab.research.google.com/github/divakar9819/DEEPSORT/blob/master/DeepSort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch

# %%
# %cd gdrive/My\ Drive/
# Out:
# /content/gdrive/My Drive

# %%
# !ls
# Out:
#  brain_tumer.zip    dataset    DriveUploader	      test
# 'Colab Notebooks'   deepSort  'Getting started.pdf'

# %%
# !mkdir deepSort

# %%
# %cd deepSort
# Out:
# /content/gdrive/My Drive/deepSort

# %%
# !git clone https://github.com/ZQPei/deep_sort_pytorch.git
# Out:
# Cloning into 'deep_sort_pytorch'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 645 (delta 1), reused 7 (delta 0), pack-reused 631
# Receiving objects: 100% (645/645), 23.69 MiB | 16.05 MiB/s, done.
# Resolving deltas: 100% (307/307), done.

# %%
# %cd deep_sort_pytorch/
# Out:
# [Errno 2] No such file or directory: 'deep_sort_pytorch/'
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch

# %%
# !ls
# Out:
# configs    detector	      README.md		webserver
# deep_sort  LICENSE	      requirements.txt	yolov3_deepsort_eval.py
# demo	   output	      scripts		yolov3_deepsort.py
# demo.avi   ped_det_server.py  utils

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 71kB 2.9MB/s
# ...
#      |████████████████████████████████| 296kB 8.8MB/s
# ...
#      |████████████████████████████████| 1.5MB 42.8MB/s
# ...
#      |████████████████████████████████| 51kB 6.3MB/s
# ...
#      |████████████████████████████████| 153kB 43.0MB/s
# ...
#      |████████████████████████████████| 20.2MB 72.9MB/s
# ...
#      |████████████████████████████████| 28.2MB 165kB/s
# ...
#      |████████████████████████████████| 174kB 49.9MB/s
# ...
#      |████████████████████████████████| 10.0MB 45.0MB/s
# ...
#      |████████████████████████████████| 2.1MB 40.0MB/s
# ...
#      |████████████████████████████████| 92kB 10.5MB/s
# ...
#      |████████████████████████████████| 51kB 5.7MB/s
# ...
#      |████████████████████████████████| 61kB 6.8MB/s
# ...
#      |████████████████████████████████| 256kB 38.8MB/s
# ...
#      |████████████████████████████████| 51kB 5.7MB/s
# ...
#      |████████████████████████████████| 512kB 41.2MB/s
# ...
#      |████████████████████████████████| 276kB 50.0MB/s
# ...

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/My\ Drive/deepSort/deep_sort_pytorch/
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/deepSort/deep_sort_pytorch/'
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch

# %%
# %cd detector/YOLOv3/weight/
# !wget https://pjreddie.com/media/files/yolov3.weights
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch/detector/YOLOv3/weight
# --2020-06-03 10:30:35--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  78.3KB/s    in 48m 12s
#
# 2020-06-03 11:18:48 (83.7 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# --2020-06-03 11:18:50--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# ...

# %%
# %cd
# Out:
# [Errno 2] No such file or directory: 'deep_sort_pytorch/'
# /

# %%
# %cd /content
# Out:
# /content

# %%
# %cd gdrive/My\ Drive/
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/'
# /content

# %%
# %cd deepSort
# Out:
# /content/gdrive/My Drive/deepSort

# %%
# %cd deep_sort_pytorch
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch

# %%
# %cd detector/YOLOv3/nms
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch/detector/YOLOv3/nms

# %%
# !sh build.sh
# Out:
# running build_ext
# /usr/local/lib/python3.6/dist-packages/torch/utils/cpp_extension.py:304: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# running develop
# running egg_info
# writing torch_extension.egg-info/PKG-INFO
# writing dependency_links to torch_extension.egg-info/dependency_links.txt
# writing top-level names to torch_extension.egg-info/top_level.txt
# writing manifest file 'torch_extension.egg-info/SOURCES.txt'
# running build_ext
# copying build/lib.linux-x86_64-3.6/torch_extension.cpython-36m-x86_64-linux-gnu.so ->
# Creating /usr/local/lib/python3.6/dist-packages/torch-extension.egg-link (link to .)
# Adding torch-extension 0.1 to easy-install.pth file
#
# Installed /content/gdrive/My Drive/deepSort/deep_sort_pytorch/detector/YOLOv3/nms/ext
# Processing dependencies for torch-extension==0.1
# ...

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch/detector/YOLOv3/nms

# %%
# %cd ../../..
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch

# %%
# !python yolov3_deepsort.py demo.avi
# Out:
# 2020-06-03 16:55:50 [INFO]: Loading weights from ./detector/YOLOv3/weight/yolov3.weights... Done!
# 2020-06-03 16:56:01 [INFO]: Loading weights from ./deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2020-06-03 16:56:03 [INFO]: Save results to ./output/
# 2020-06-03 16:56:04 [INFO]: time: 0.428s, fps: 2.334, detection numbers: 8, tracking numbers: 0
# 2020-06-03 16:56:04 [INFO]: time: 0.059s, fps: 16.999, detection numbers: 8, tracking numbers: 0
# 2020-06-03 16:56:04 [INFO]: time: 0.038s, fps: 26.379, detection numbers: 0, tracking numbers: 0
# 2020-06-03 16:56:04 [INFO]: time: 0.037s, fps: 26.942, detection numbers: 0, tracking numbers: 0
# 2020-06-03 16:56:04 [INFO]: time: 0.037s, fps: 26.785, detection numbers: 0, tracking numbers: 0
# 2020-06-03 16:56:04 [INFO]: time: 0.037s, fps: 27.032, detection numbers: 0, tracking numbers: 0
# 2020-06-03 16:56:04 [INFO]: time: 0.037s, fps: 26.787, detection numbers: 0, tracking numbers: 0
# ...

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/deepSort/deep_sort_pytorch
